# %% [markdown]
# # Problem 7

# %%
# Importing relevant packages and doing necessary setup
import cv2
import matplotlib.pyplot as plt
import matplotlib
import PIL
import numpy as np

# %matplotlib inline

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
# Helper function to display multiple images in a plot
def display_images(images, rows, cols, size, title, subtitles):
    fig = plt.figure(figsize = size)
    c = 0
    sz = len(images)
    for i in range(rows):
        for j in range(cols):
            if sz == c:
                break
            ax1 = fig.add_subplot(rows, cols, c + 1)
            ax1.imshow(images[c], cmap = 'gray')
            ax1.set_title(subtitles[c], fontsize = 20)
            c = c + 1
    plt.show()
    # Un comment the below line and comment the above line to save and display
    #plt.savefig('part2.png')

# %% [markdown]
# ### Part 1

# %%
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
images = []
subtitles = []
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Original Image')
subtitles.append('Frequency Spectrum of Original Image')
k = 2
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 2')
subtitles.append('Frequency Spectrum of Sampled Image(n = 2)')
display_images(images, 2, 2, (20, 20), '', subtitles)

# %%
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
images = []
subtitles = []
k = 3
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 3')
subtitles.append('Frequency Spectrum of Sampled Image(n = 3)')
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
k = 4
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 4')
subtitles.append('Frequency Spectrum of Sampled Image(n = 4)')

display_images(images, 2, 2, (20, 20), '', subtitles)

# %%
images = []
subtitles = []
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
k = 5
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 5')
subtitles.append('Frequency Spectrum of Sampled Image(n = 5)')

img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
k = 6
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 6')
subtitles.append('Frequency Spectrum of Sampled Image(n = 6)')

display_images(images, 2, 2, (20, 20), '', subtitles)

# %%
images = []
subtitles = []
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
k = 7
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 7')
subtitles.append('Frequency Spectrum of Sampled Image(n = 7)')

img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
k = 8
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 8')
subtitles.append('Frequency Spectrum of Sampled Image(n = 8)')

display_images(images, 2, 2, (20, 20), '', subtitles)

# %% [markdown]
# Nyquist Rate = 4

# %% [markdown]
# ### Part 2

# %%
img = cv2.imread('../input_data/bricks.jpg', cv2.IMREAD_GRAYSCALE)
images = []
subtitles = []
images.append(img)

f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
cut_off = 20
new_transform = np.copy(fshift)
rows = new_transform.shape[0]
cols = new_transform.shape[1]
for i in range(rows):
    for j in range(cols):
        D = np.sqrt((i - (rows / 2)) * (i - (rows / 2)) + (j - (cols / 2)) * (j - (cols / 2))) 
        new_transform[i][j] = np.exp(-(D * D) / (2 * cut_off * cut_off)) * fshift[i][j]

f_ishift = np.fft.ifftshift(new_transform)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)
img = img_back
images.append(img)
subtitles.append('Original Image')
subtitles.append('Blurred Image')
display_images(images, 2, 1, (20, 20), '', subtitles)

# %%
images = []
subtitles = []
tmp = img
k = 3
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 3')
subtitles.append('Frequency Spectrum of Sampled Image(n = 3)')
img = tmp
k = 4
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 4')
subtitles.append('Frequency Spectrum of Sampled Image(n = 4)')

display_images(images, 2, 2, (20, 20), '', subtitles)

# %%
images = []
subtitles = []
img = tmp
k = 5
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 5')
subtitles.append('Frequency Spectrum of Sampled Image(n = 5)')
img = tmp
k = 9
img = img[0:img.shape[0]:k, 0:img.shape[1]:k]
images.append(img)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(1 + np.abs(fshift))
images.append(magnitude_spectrum)
subtitles.append('Sampled at n = 9')
subtitles.append('Frequency Spectrum of Sampled Image(n = 9)')

display_images(images, 2, 2, (20, 20), '', subtitles)

# %% [markdown]
# - Nyquist rate increases with blurring
